# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/py-crack/Segmentation/Ground truth/173.png
# /kaggle/input/py-crack/Segmentation/Ground truth/248.png
# /kaggle/input/py-crack/Segmentation/Ground truth/94.png
# /kaggle/input/py-crack/Segmentation/Ground truth/236.png
# /kaggle/input/py-crack/Segmentation/Ground truth/340.png
# /kaggle/input/py-crack/Segmentation/Ground truth/48.png
# /kaggle/input/py-crack/Segmentation/Ground truth/350.png
# /kaggle/input/py-crack/Segmentation/Ground truth/314.png
# /kaggle/input/py-crack/Segmentation/Ground truth/227.png
# /kaggle/input/py-crack/Segmentation/Ground truth/238.png
# /kaggle/input/py-crack/Segmentation/Ground truth/61.png
# /kaggle/input/py-crack/Segmentation/Ground truth/222.png
# /kaggle/input/py-crack/Segmentation/Ground truth/330.png
# /kaggle/input/py-crack/Segmentation/Ground truth/278.png
# /kaggle/input/py-crack/Segmentation/Ground truth/303.png
# /kaggle/input/py-crack/Segmentation/Ground truth/37.png
# /kaggle/input/py-crack/Segmentation/Ground truth/231.png
# /kaggle/input/py-crack/Segmentation/Ground truth/348.png
# /kaggle/input/py-crack/Segmentation/Ground truth/353.png
# /kaggle/input/py-crack/Segmentation/Ground truth/148.png
# /kaggle/input/py-crack/Segmentation/Ground truth/352.png
# /kaggle/input/py-crack/Segmentation/Ground truth/35.png
# /kaggle/input/py-crack/Segmentation/Ground truth/232.png
# /kaggle/input/py-crack/Segmentation/Ground truth/334.png
# /kaggle/input/py-crack/Segmentation/Ground truth/177.png
# /kaggle/input/py-crack/Segmentation/Ground truth/142.png
# /kaggle/input/py-crack/Segmentation/Ground truth/104.png
# /kaggle/input/py-crack/Segmentation/Ground truth/133.png
# /kaggle/input/py-crack/Segmentation/Ground truth/70.png
# /kaggle/input/py-crack/Segmentation/Ground truth/162.png
# /kaggle/input/py-crack/Segmentation/Ground truth/186.png
# /kaggle/input/py-crack/Segmentation/Ground truth/73.png
# /kaggle/input/py-crack/Segmentation/Ground truth/92.png
# /kaggle/input/py-crack/Segmentation/Ground truth/315.png
# /kaggle/input/py-crack/Segmentation/Ground truth/359.png
# /kaggle/input/py-crack/Segmentation/Ground truth/261.png
# /kaggle/input/py-crack/Segmentation/Ground truth/153.png
# /kaggle/input/py-crack/Segmentation/Ground truth/167.png
# /kaggle/input/py-crack/Segmentation/Ground truth/204.png
# /kaggle/input/py-crack/Segmentation/Ground truth/75.png
# /kaggle/input/py-crack/Segmentation/Ground truth/296.png
# /kaggle/input/py-crack/Segmentation/Ground truth/270.png
# /kaggle/input/py-crack/Segmentation/Ground truth/89.png
# /kaggle/input/py-crack/Segmentation/Ground truth/338.png
# /kaggle/input/py-crack/Segmentation/Ground truth/333.png
# /kaggle/input/py-crack/Segmentation/Ground truth/164.png
# /kaggle/input/py-crack/Segmentation/Ground truth/11.png
# /kaggle/input/py-crack/Segmentation/Ground truth/351.png
# /kaggle/input/py-crack/Segmentation/Ground truth/213.png
# /kaggle/input/py-crack/Segmentation/Ground truth/114.png
# /kaggle/input/py-crack/Segmentation/Ground truth/302.png
# /kaggle/input/py-crack/Segmentation/Ground truth/185.png
# /kaggle/input/py-crack/Segmentation/Ground truth/240.png
# /kaggle/input/py-crack/Segmentation/Ground truth/317.png
# /kaggle/input/py-crack/Segmentation/Ground truth/281.png
# /kaggle/input/py-crack/Segmentation/Ground truth/344.png
# /kaggle/input/py-crack/Segmentation/Ground truth/362.png
# /kaggle/input/py-crack/Segmentation/Ground truth/176.png
# /kaggle/input/py-crack/Segmentation/Ground truth/95.png
# /kaggle/input/py-crack/Segmentation/Ground truth/97.png
# /kaggle/input/py-crack/Segmentation/Ground truth/124.png
# /kaggle/input/py-crack/Segmentation/Ground truth/119.png
# /kaggle/input/py-crack/Segmentation/Ground truth/256.png
# /kaggle/input/py-crack/Segmentation/Ground truth/100.png
# /kaggle/input/py-crack/Segmentation/Ground truth/211.png
# /kaggle/input/py-crack/Segmentation/Ground truth/322.png
# /kaggle/input/py-crack/Segmentation/Ground truth/76.png
# /kaggle/input/py-crack/Segmentation/Ground truth/193.png
# /kaggle/input/py-crack/Segmentation/Ground truth/191.png
# /kaggle/input/py-crack/Segmentation/Ground truth/163.png
# /kaggle/input/py-crack/Segmentation/Ground truth/31.png
# /kaggle/input/py-crack/Segmentation/Ground truth/138.png
# /kaggle/input/py-crack/Segmentation/Ground truth/4.png
# /kaggle/input/py-crack/Segmentation/Ground truth/225.png
# /kaggle/input/py-crack/Segmentation/Ground truth/192.png
# /kaggle/input/py-crack/Segmentation/Ground truth/43.png
# /kaggle/input/py-crack/Segmentation/Ground truth/229.png
# /kaggle/input/py-crack/Segmentation/Ground truth/129.png
# /kaggle/input/py-crack/Segmentation/Ground truth/331.png
# /kaggle/input/py-crack/Segmentation/Ground truth/313.png
# /kaggle/input/py-crack/Segmentation/Ground truth/345.png
# /kaggle/input/py-crack/Segmentation/Ground truth/171.png
# /kaggle/input/py-crack/Segmentation/Ground truth/287.png
# /kaggle/input/py-crack/Segmentation/Ground truth/324.png
# /kaggle/input/py-crack/Segmentation/Ground truth/145.png
# /kaggle/input/py-crack/Segmentation/Ground truth/40.png
# /kaggle/input/py-crack/Segmentation/Ground truth/209.png
# /kaggle/input/py-crack/Segmentation/Ground truth/197.png
# /kaggle/input/py-crack/Segmentation/Ground truth/311.png
# /kaggle/input/py-crack/Segmentation/Ground truth/33.png
# /kaggle/input/py-crack/Segmentation/Ground truth/126.png
# /kaggle/input/py-crack/Segmentation/Ground truth/147.png
# /kaggle/input/py-crack/Segmentation/Ground truth/326.png
# /kaggle/input/py-crack/Segmentation/Ground truth/357.png
# /kaggle/input/py-crack/Segmentation/Ground truth/85.png
# /kaggle/input/py-crack/Segmentation/Ground truth/9.png
# /kaggle/input/py-crack/Segmentation/Ground truth/102.png
# /kaggle/input/py-crack/Segmentation/Ground truth/254.png
# /kaggle/input/py-crack/Segmentation/Ground truth/245.png
# /kaggle/input/py-crack/Segmentation/Ground truth/168.png
# /kaggle/input/py-crack/Segmentation/Ground truth/233.png
# /kaggle/input/py-crack/Segmentation/Ground truth/200.png
# /kaggle/input/py-crack/Segmentation/Ground truth/255.png
# /kaggle/input/py-crack/Segmentation/Ground truth/284.png
# /kaggle/input/py-crack/Segmentation/Ground truth/56.png
# /kaggle/input/py-crack/Segmentation/Ground truth/116.png
# /kaggle/input/py-crack/Segmentation/Ground truth/299.png
# /kaggle/input/py-crack/Segmentation/Ground truth/80.png
# /kaggle/input/py-crack/Segmentation/Ground truth/55.png
# /kaggle/input/py-crack/Segmentation/Ground truth/280.png
# /kaggle/input/py-crack/Segmentation/Ground truth/130.png
# /kaggle/input/py-crack/Segmentation/Ground truth/291.png
# /kaggle/input/py-crack/Segmentation/Ground truth/50.png
# /kaggle/input/py-crack/Segmentation/Ground truth/288.png
# /kaggle/input/py-crack/Segmentation/Ground truth/307.png
# /kaggle/input/py-crack/Segmentation/Ground truth/218.png
# /kaggle/input/py-crack/Segmentation/Ground truth/199.png
# /kaggle/input/py-crack/Segmentation/Ground truth/112.png
# /kaggle/input/py-crack/Segmentation/Ground truth/49.png
# /kaggle/input/py-crack/Segmentation/Ground truth/327.png
# /kaggle/input/py-crack/Segmentation/Ground truth/268.png
# /kaggle/input/py-crack/Segmentation/Ground truth/93.png
# /kaggle/input/py-crack/Segmentation/Ground truth/150.png
# /kaggle/input/py-crack/Segmentation/Ground truth/113.png
# /kaggle/input/py-crack/Segmentation/Ground truth/332.png
# /kaggle/input/py-crack/Segmentation/Ground truth/59.png
# /kaggle/input/py-crack/Segmentation/Ground truth/316.png
# /kaggle/input/py-crack/Segmentation/Ground truth/169.png
# /kaggle/input/py-crack/Segmentation/Ground truth/301.png
# /kaggle/input/py-crack/Segmentation/Ground truth/289.png
# /kaggle/input/py-crack/Segmentation/Ground truth/170.png
# /kaggle/input/py-crack/Segmentation/Ground truth/194.png
# /kaggle/input/py-crack/Segmentation/Ground truth/136.png
# /kaggle/input/py-crack/Segmentation/Ground truth/198.png
# /kaggle/input/py-crack/Segmentation/Ground truth/14.png
# /kaggle/input/py-crack/Segmentation/Ground truth/65.png
# /kaggle/input/py-crack/Segmentation/Ground truth/161.png
# /kaggle/input/py-crack/Segmentation/Ground truth/1.png
# /kaggle/input/py-crack/Segmentation/Ground truth/293.png
# /kaggle/input/py-crack/Segmentation/Ground truth/367.png
# /kaggle/input/py-crack/Segmentation/Ground truth/325.png
# /kaggle/input/py-crack/Segmentation/Ground truth/108.png
# /kaggle/input/py-crack/Segmentation/Ground truth/39.png
# /kaggle/input/py-crack/Segmentation/Ground truth/360.png
# /kaggle/input/py-crack/Segmentation/Ground truth/132.png
# /kaggle/input/py-crack/Segmentation/Ground truth/156.png
# /kaggle/input/py-crack/Segmentation/Ground truth/319.png
# /kaggle/input/py-crack/Segmentation/Ground truth/107.png
# /kaggle/input/py-crack/Segmentation/Ground truth/90.png
# /kaggle/input/py-crack/Segmentation/Ground truth/262.png
# /kaggle/input/py-crack/Segmentation/Ground truth/364.png
# /kaggle/input/py-crack/Segmentation/Ground truth/215.png
# /kaggle/input/py-crack/Segmentation/Ground truth/20.png
# /kaggle/input/py-crack/Segmentation/Ground truth/181.png
# /kaggle/input/py-crack/Segmentation/Ground truth/83.png
# /kaggle/input/py-crack/Segmentation/Ground truth/38.png
# /kaggle/input/py-crack/Segmentation/Ground truth/151.png
# /kaggle/input/py-crack/Segmentation/Ground truth/2.png
# /kaggle/input/py-crack/Segmentation/Ground truth/349.png
# /kaggle/input/py-crack/Segmentation/Ground truth/335.png
# /kaggle/input/py-crack/Segmentation/Ground truth/223.png
# /kaggle/input/py-crack/Segmentation/Ground truth/272.png
# /kaggle/input/py-crack/Segmentation/Ground truth/10.png
# /kaggle/input/py-crack/Segmentation/Ground truth/82.png
# /kaggle/input/py-crack/Segmentation/Ground truth/242.png
# /kaggle/input/py-crack/Segmentation/Ground truth/251.png
# /kaggle/input/py-crack/Segmentation/Ground truth/174.png
# /kaggle/input/py-crack/Segmentation/Ground truth/250.png
# /kaggle/input/py-crack/Segmentation/Ground truth/131.png
# /kaggle/input/py-crack/Segmentation/Ground truth/36.png
# /kaggle/input/py-crack/Segmentation/Ground truth/157.png
# /kaggle/input/py-crack/Segmentation/Ground truth/182.png
# /kaggle/input/py-crack/Segmentation/Ground truth/143.png
# /kaggle/input/py-crack/Segmentation/Ground truth/221.png
# /kaggle/input/py-crack/Segmentation/Ground truth/208.png
# /kaggle/input/py-crack/Segmentation/Ground truth/152.png
# /kaggle/input/py-crack/Segmentation/Ground truth/137.png
# /kaggle/input/py-crack/Segmentation/Ground truth/312.png
# /kaggle/input/py-crack/Segmentation/Ground truth/81.png
# /kaggle/input/py-crack/Segmentation/Ground truth/239.png
# /kaggle/input/py-crack/Segmentation/Ground truth/66.png
# /kaggle/input/py-crack/Segmentation/Ground truth/58.png
# /kaggle/input/py-crack/Segmentation/Ground truth/214.png
# /kaggle/input/py-crack/Segmentation/Ground truth/122.png
# /kaggle/input/py-crack/Segmentation/Ground truth/339.png
# /kaggle/input/py-crack/Segmentation/Ground truth/276.png
# /kaggle/input/py-crack/Segmentation/Ground truth/187.png
# /kaggle/input/py-crack/Segmentation/Ground truth/106.png
# /kaggle/input/py-crack/Segmentation/Ground truth/336.png
# /kaggle/input/py-crack/Segmentation/Ground truth/279.png
# /kaggle/input/py-crack/Segmentation/Ground truth/356.png
# /kaggle/input/py-crack/Segmentation/Ground truth/117.png
# /kaggle/input/py-crack/Segmentation/Ground truth/220.png
# /kaggle/input/py-crack/Segmentation/Ground truth/277.png
# /kaggle/input/py-crack/Segmentation/Ground truth/300.png
# /kaggle/input/py-crack/Segmentation/Ground truth/244.png
# /kaggle/input/py-crack/Segmentation/Ground truth/329.png
# /kaggle/input/py-crack/Segmentation/Ground truth/282.png
# /kaggle/input/py-crack/Segmentation/Ground truth/263.png
# /kaggle/input/py-crack/Segmentation/Ground truth/354.png
# /kaggle/input/py-crack/Segmentation/Ground truth/166.png
# /kaggle/input/py-crack/Segmentation/Ground truth/320.png
# /kaggle/input/py-crack/Segmentation/Ground truth/18.png
# /kaggle/input/py-crack/Segmentation/Ground truth/63.png
# /kaggle/input/py-crack/Segmentation/Ground truth/294.png
# /kaggle/input/py-crack/Segmentation/Ground truth/264.png
# /kaggle/input/py-crack/Segmentation/Ground truth/21.png
# /kaggle/input/py-crack/Segmentation/Ground truth/12.png
# /kaggle/input/py-crack/Segmentation/Ground truth/98.png
# /kaggle/input/py-crack/Segmentation/Ground truth/127.png
# /kaggle/input/py-crack/Segmentation/Ground truth/219.png
# /kaggle/input/py-crack/Segmentation/Ground truth/184.png
# /kaggle/input/py-crack/Segmentation/Ground truth/28.png
# /kaggle/input/py-crack/Segmentation/Ground truth/190.png
# /kaggle/input/py-crack/Segmentation/Ground truth/165.png
# /kaggle/input/py-crack/Segmentation/Ground truth/22.png
# /kaggle/input/py-crack/Segmentation/Ground truth/202.png
# /kaggle/input/py-crack/Segmentation/Ground truth/247.png
# /kaggle/input/py-crack/Segmentation/Ground truth/368.png
# /kaggle/input/py-crack/Segmentation/Ground truth/67.png
# /kaggle/input/py-crack/Segmentation/Ground truth/96.png
# /kaggle/input/py-crack/Segmentation/Ground truth/243.png
# /kaggle/input/py-crack/Segmentation/Ground truth/34.png
# /kaggle/input/py-crack/Segmentation/Ground truth/41.png
# /kaggle/input/py-crack/Segmentation/Ground truth/159.png
# /kaggle/input/py-crack/Segmentation/Ground truth/246.png
# /kaggle/input/py-crack/Segmentation/Ground truth/195.png
# /kaggle/input/py-crack/Segmentation/Ground truth/105.png
# /kaggle/input/py-crack/Segmentation/Ground truth/125.png
# /kaggle/input/py-crack/Segmentation/Ground truth/121.png
# /kaggle/input/py-crack/Segmentation/Ground truth/318.png
# /kaggle/input/py-crack/Segmentation/Ground truth/216.png
# /kaggle/input/py-crack/Segmentation/Ground truth/337.png
# /kaggle/input/py-crack/Segmentation/Ground truth/69.png
# /kaggle/input/py-crack/Segmentation/Ground truth/146.png
# /kaggle/input/py-crack/Segmentation/Ground truth/154.png
# /kaggle/input/py-crack/Segmentation/Ground truth/267.png
# /kaggle/input/py-crack/Segmentation/Ground truth/7.png
# /kaggle/input/py-crack/Segmentation/Ground truth/366.png
# /kaggle/input/py-crack/Segmentation/Ground truth/241.png
# /kaggle/input/py-crack/Segmentation/Ground truth/188.png
# /kaggle/input/py-crack/Segmentation/Ground truth/86.png
# /kaggle/input/py-crack/Segmentation/Ground truth/258.png
# /kaggle/input/py-crack/Segmentation/Ground truth/77.png
# /kaggle/input/py-crack/Segmentation/Ground truth/290.png
# /kaggle/input/py-crack/Segmentation/Ground truth/29.png
# /kaggle/input/py-crack/Segmentation/Ground truth/265.png
# /kaggle/input/py-crack/Segmentation/Ground truth/103.png
# /kaggle/input/py-crack/Segmentation/Ground truth/72.png
# /kaggle/input/py-crack/Segmentation/Ground truth/144.png
# /kaggle/input/py-crack/Segmentation/Ground truth/298.png
# /kaggle/input/py-crack/Segmentation/Ground truth/109.png
# /kaggle/input/py-crack/Segmentation/Ground truth/224.png
# /kaggle/input/py-crack/Segmentation/Ground truth/361.png
# /kaggle/input/py-crack/Segmentation/Ground truth/71.png
# /kaggle/input/py-crack/Segmentation/Ground truth/74.png
# /kaggle/input/py-crack/Segmentation/Ground truth/120.png
# /kaggle/input/py-crack/Segmentation/Ground truth/271.png
# /kaggle/input/py-crack/Segmentation/Ground truth/363.png
# /kaggle/input/py-crack/Segmentation/Ground truth/310.png
# /kaggle/input/py-crack/Segmentation/Ground truth/323.png
# /kaggle/input/py-crack/Segmentation/Ground truth/118.png
# /kaggle/input/py-crack/Segmentation/Ground truth/17.png
# /kaggle/input/py-crack/Segmentation/Ground truth/53.png
# /kaggle/input/py-crack/Segmentation/Ground truth/266.png
# /kaggle/input/py-crack/Segmentation/Ground truth/196.png
# /kaggle/input/py-crack/Segmentation/Ground truth/179.png
# /kaggle/input/py-crack/Segmentation/Ground truth/178.png
# /kaggle/input/py-crack/Segmentation/Ground truth/160.png
# /kaggle/input/py-crack/Segmentation/Ground truth/140.png
# /kaggle/input/py-crack/Segmentation/Ground truth/52.png
# /kaggle/input/py-crack/Segmentation/Ground truth/5.png
# /kaggle/input/py-crack/Segmentation/Ground truth/139.png
# /kaggle/input/py-crack/Segmentation/Ground truth/3.png
# /kaggle/input/py-crack/Segmentation/Ground truth/172.png
# /kaggle/input/py-crack/Segmentation/Ground truth/64.png
# /kaggle/input/py-crack/Segmentation/Ground truth/347.png
# /kaggle/input/py-crack/Segmentation/Ground truth/355.png
# /kaggle/input/py-crack/Segmentation/Ground truth/16.png
# /kaggle/input/py-crack/Segmentation/Ground truth/328.png
# /kaggle/input/py-crack/Segmentation/Ground truth/203.png
# /kaggle/input/py-crack/Segmentation/Ground truth/8.png
# /kaggle/input/py-crack/Segmentation/Ground truth/45.png
# /kaggle/input/py-crack/Segmentation/Ground truth/24.png
# /kaggle/input/py-crack/Segmentation/Ground truth/32.png
# /kaggle/input/py-crack/Segmentation/Ground truth/88.png
# /kaggle/input/py-crack/Segmentation/Ground truth/283.png
# /kaggle/input/py-crack/Segmentation/Ground truth/274.png
# /kaggle/input/py-crack/Segmentation/Ground truth/115.png
# /kaggle/input/py-crack/Segmentation/Ground truth/249.png
# /kaggle/input/py-crack/Segmentation/Ground truth/128.png
# /kaggle/input/py-crack/Segmentation/Ground truth/158.png
# /kaggle/input/py-crack/Segmentation/Ground truth/6.png
# /kaggle/input/py-crack/Segmentation/Ground truth/23.png
# /kaggle/input/py-crack/Segmentation/Ground truth/87.png
# /kaggle/input/py-crack/Segmentation/Ground truth/275.png
# /kaggle/input/py-crack/Segmentation/Ground truth/51.png
# /kaggle/input/py-crack/Segmentation/Ground truth/101.png
# /kaggle/input/py-crack/Segmentation/Ground truth/297.png
# /kaggle/input/py-crack/Segmentation/Ground truth/135.png
# /kaggle/input/py-crack/Segmentation/Ground truth/123.png
# /kaggle/input/py-crack/Segmentation/Ground truth/91.png
# /kaggle/input/py-crack/Segmentation/Ground truth/230.png
# /kaggle/input/py-crack/Segmentation/Ground truth/44.png
# /kaggle/input/py-crack/Segmentation/Ground truth/189.png
# /kaggle/input/py-crack/Segmentation/Ground truth/343.png
# /kaggle/input/py-crack/Segmentation/Ground truth/68.png
# /kaggle/input/py-crack/Segmentation/Ground truth/286.png
# /kaggle/input/py-crack/Segmentation/Ground truth/180.png
# /kaggle/input/py-crack/Segmentation/Ground truth/46.png
# /kaggle/input/py-crack/Segmentation/Ground truth/57.png
# /kaggle/input/py-crack/Segmentation/Ground truth/84.png
# /kaggle/input/py-crack/Segmentation/Ground truth/15.png
# /kaggle/input/py-crack/Segmentation/Ground truth/210.png
# /kaggle/input/py-crack/Segmentation/Ground truth/234.png
# /kaggle/input/py-crack/Segmentation/Ground truth/358.png
# /kaggle/input/py-crack/Segmentation/Ground truth/365.png
# /kaggle/input/py-crack/Segmentation/Ground truth/252.png
# /kaggle/input/py-crack/Segmentation/Ground truth/183.png
# /kaggle/input/py-crack/Segmentation/Ground truth/30.png
# /kaggle/input/py-crack/Segmentation/Ground truth/321.png
# /kaggle/input/py-crack/Segmentation/Ground truth/60.png
# /kaggle/input/py-crack/Segmentation/Ground truth/235.png
# /kaggle/input/py-crack/Segmentation/Ground truth/99.png
# /kaggle/input/py-crack/Segmentation/Ground truth/155.png
# /kaggle/input/py-crack/Segmentation/Ground truth/228.png
# /kaggle/input/py-crack/Segmentation/Ground truth/27.png
# /kaggle/input/py-crack/Segmentation/Ground truth/237.png
# /kaggle/input/py-crack/Segmentation/Ground truth/292.png
# /kaggle/input/py-crack/Segmentation/Ground truth/201.png
# /kaggle/input/py-crack/Segmentation/Ground truth/295.png
# /kaggle/input/py-crack/Segmentation/Ground truth/273.png
# /kaggle/input/py-crack/Segmentation/Ground truth/269.png
# /kaggle/input/py-crack/Segmentation/Ground truth/78.png
# /kaggle/input/py-crack/Segmentation/Ground truth/212.png
# /kaggle/input/py-crack/Segmentation/Ground truth/47.png
# /kaggle/input/py-crack/Segmentation/Ground truth/207.png
# /kaggle/input/py-crack/Segmentation/Ground truth/149.png
# /kaggle/input/py-crack/Segmentation/Ground truth/13.png
# /kaggle/input/py-crack/Segmentation/Ground truth/260.png
# /kaggle/input/py-crack/Segmentation/Ground truth/253.png
# /kaggle/input/py-crack/Segmentation/Ground truth/206.png
# /kaggle/input/py-crack/Segmentation/Ground truth/342.png
# /kaggle/input/py-crack/Segmentation/Ground truth/346.png
# /kaggle/input/py-crack/Segmentation/Ground truth/134.png
# /kaggle/input/py-crack/Segmentation/Ground truth/259.png
# /kaggle/input/py-crack/Segmentation/Ground truth/25.png
# /kaggle/input/py-crack/Segmentation/Ground truth/285.png
# /kaggle/input/py-crack/Segmentation/Ground truth/341.png
# /kaggle/input/py-crack/Segmentation/Ground truth/54.png
# /kaggle/input/py-crack/Segmentation/Ground truth/111.png
# /kaggle/input/py-crack/Segmentation/Ground truth/62.png
# /kaggle/input/py-crack/Segmentation/Ground truth/205.png
# /kaggle/input/py-crack/Segmentation/Ground truth/369.png
# /kaggle/input/py-crack/Segmentation/Ground truth/141.png
# /kaggle/input/py-crack/Segmentation/Ground truth/309.png
# /kaggle/input/py-crack/Segmentation/Ground truth/19.png
# /kaggle/input/py-crack/Segmentation/Ground truth/110.png
# /kaggle/input/py-crack/Segmentation/Ground truth/308.png
# /kaggle/input/py-crack/Segmentation/Ground truth/26.png
# /kaggle/input/py-crack/Segmentation/Ground truth/79.png
# /kaggle/input/py-crack/Segmentation/Ground truth/257.png
# /kaggle/input/py-crack/Segmentation/Ground truth/305.png
# /kaggle/input/py-crack/Segmentation/Ground truth/42.png
# /kaggle/input/py-crack/Segmentation/Ground truth/175.png
# /kaggle/input/py-crack/Segmentation/Ground truth/226.png
# /kaggle/input/py-crack/Segmentation/Ground truth/217.png
# /kaggle/input/py-crack/Segmentation/Ground truth/306.png
# /kaggle/input/py-crack/Segmentation/Ground truth/304.png
# /kaggle/input/py-crack/Segmentation/Original image/208.jpg
# /kaggle/input/py-crack/Segmentation/Original image/333.jpg
# /kaggle/input/py-crack/Segmentation/Original image/45.jpg
# /kaggle/input/py-crack/Segmentation/Original image/369.jpg
# /kaggle/input/py-crack/Segmentation/Original image/56.jpg
# /kaggle/input/py-crack/Segmentation/Original image/89.jpg
# /kaggle/input/py-crack/Segmentation/Original image/20.jpg
# /kaggle/input/py-crack/Segmentation/Original image/275.jpg
# /kaggle/input/py-crack/Segmentation/Original image/212.jpg
# /kaggle/input/py-crack/Segmentation/Original image/239.jpg
# /kaggle/input/py-crack/Segmentation/Original image/58.jpg
# /kaggle/input/py-crack/Segmentation/Original image/150.jpg
# /kaggle/input/py-crack/Segmentation/Original image/6.jpg
# /kaggle/input/py-crack/Segmentation/Original image/109.jpg
# /kaggle/input/py-crack/Segmentation/Original image/149.jpg
# /kaggle/input/py-crack/Segmentation/Original image/187.jpg
# /kaggle/input/py-crack/Segmentation/Original image/76.jpg
# /kaggle/input/py-crack/Segmentation/Original image/355.jpg
# /kaggle/input/py-crack/Segmentation/Original image/71.jpg
# /kaggle/input/py-crack/Segmentation/Original image/342.jpg
# /kaggle/input/py-crack/Segmentation/Original image/272.jpg
# /kaggle/input/py-crack/Segmentation/Original image/270.jpg
# /kaggle/input/py-crack/Segmentation/Original image/182.jpg
# /kaggle/input/py-crack/Segmentation/Original image/215.jpg
# /kaggle/input/py-crack/Segmentation/Original image/185.jpg
# /kaggle/input/py-crack/Segmentation/Original image/243.jpg
# /kaggle/input/py-crack/Segmentation/Original image/153.jpg
# /kaggle/input/py-crack/Segmentation/Original image/189.jpg
# /kaggle/input/py-crack/Segmentation/Original image/143.jpg
# /kaggle/input/py-crack/Segmentation/Original image/327.jpg
# /kaggle/input/py-crack/Segmentation/Original image/253.jpg
# /kaggle/input/py-crack/Segmentation/Original image/343.jpg
# /kaggle/input/py-crack/Segmentation/Original image/115.jpg
# /kaggle/input/py-crack/Segmentation/Original image/131.jpg
# /kaggle/input/py-crack/Segmentation/Original image/5.jpg
# /kaggle/input/py-crack/Segmentation/Original image/366.jpg
# /kaggle/input/py-crack/Segmentation/Original image/151.jpg
# /kaggle/input/py-crack/Segmentation/Original image/8.jpg
# /kaggle/input/py-crack/Segmentation/Original image/260.jpg
# /kaggle/input/py-crack/Segmentation/Original image/202.jpg
# /kaggle/input/py-crack/Segmentation/Original image/84.jpg
# /kaggle/input/py-crack/Segmentation/Original image/237.jpg
# /kaggle/input/py-crack/Segmentation/Original image/273.jpg
# /kaggle/input/py-crack/Segmentation/Original image/286.jpg
# /kaggle/input/py-crack/Segmentation/Original image/283.jpg
# /kaggle/input/py-crack/Segmentation/Original image/85.jpg
# /kaggle/input/py-crack/Segmentation/Original image/359.jpg
# /kaggle/input/py-crack/Segmentation/Original image/67.jpg
# /kaggle/input/py-crack/Segmentation/Original image/265.jpg
# /kaggle/input/py-crack/Segmentation/Original image/289.jpg
# /kaggle/input/py-crack/Segmentation/Original image/118.jpg
# /kaggle/input/py-crack/Segmentation/Original image/361.jpg
# /kaggle/input/py-crack/Segmentation/Original image/82.jpg
# /kaggle/input/py-crack/Segmentation/Original image/295.jpg
# /kaggle/input/py-crack/Segmentation/Original image/176.jpg
# /kaggle/input/py-crack/Segmentation/Original image/279.jpg
# /kaggle/input/py-crack/Segmentation/Original image/30.jpg
# /kaggle/input/py-crack/Segmentation/Original image/97.jpg
# /kaggle/input/py-crack/Segmentation/Original image/334.jpg
# /kaggle/input/py-crack/Segmentation/Original image/106.jpg
# /kaggle/input/py-crack/Segmentation/Original image/163.jpg
# /kaggle/input/py-crack/Segmentation/Original image/113.jpg
# /kaggle/input/py-crack/Segmentation/Original image/160.jpg
# /kaggle/input/py-crack/Segmentation/Original image/38.jpg
# /kaggle/input/py-crack/Segmentation/Original image/349.jpg
# /kaggle/input/py-crack/Segmentation/Original image/328.jpg
# /kaggle/input/py-crack/Segmentation/Original image/211.jpg
# /kaggle/input/py-crack/Segmentation/Original image/42.jpg
# /kaggle/input/py-crack/Segmentation/Original image/291.jpg
# /kaggle/input/py-crack/Segmentation/Original image/197.jpg
# /kaggle/input/py-crack/Segmentation/Original image/33.jpg
# /kaggle/input/py-crack/Segmentation/Original image/10.jpg
# /kaggle/input/py-crack/Segmentation/Original image/234.jpg
# /kaggle/input/py-crack/Segmentation/Original image/178.jpg
# /kaggle/input/py-crack/Segmentation/Original image/54.jpg
# /kaggle/input/py-crack/Segmentation/Original image/271.jpg
# /kaggle/input/py-crack/Segmentation/Original image/251.jpg
# /kaggle/input/py-crack/Segmentation/Original image/130.jpg
# /kaggle/input/py-crack/Segmentation/Original image/62.jpg
# /kaggle/input/py-crack/Segmentation/Original image/278.jpg
# /kaggle/input/py-crack/Segmentation/Original image/156.jpg
# /kaggle/input/py-crack/Segmentation/Original image/120.jpg
# /kaggle/input/py-crack/Segmentation/Original image/35.jpg
# /kaggle/input/py-crack/Segmentation/Original image/290.jpg
# /kaggle/input/py-crack/Segmentation/Original image/61.jpg
# /kaggle/input/py-crack/Segmentation/Original image/190.jpg
# /kaggle/input/py-crack/Segmentation/Original image/124.jpg
# /kaggle/input/py-crack/Segmentation/Original image/353.jpg
# /kaggle/input/py-crack/Segmentation/Original image/191.jpg
# /kaggle/input/py-crack/Segmentation/Original image/59.jpg
# /kaggle/input/py-crack/Segmentation/Original image/73.jpg
# /kaggle/input/py-crack/Segmentation/Original image/313.jpg
# /kaggle/input/py-crack/Segmentation/Original image/188.jpg
# /kaggle/input/py-crack/Segmentation/Original image/274.jpg
# /kaggle/input/py-crack/Segmentation/Original image/98.jpg
# /kaggle/input/py-crack/Segmentation/Original image/41.jpg
# /kaggle/input/py-crack/Segmentation/Original image/248.jpg
# /kaggle/input/py-crack/Segmentation/Original image/123.jpg
# /kaggle/input/py-crack/Segmentation/Original image/230.jpg
# /kaggle/input/py-crack/Segmentation/Original image/256.jpg
# /kaggle/input/py-crack/Segmentation/Original image/247.jpg
# /kaggle/input/py-crack/Segmentation/Original image/94.jpg
# /kaggle/input/py-crack/Segmentation/Original image/362.jpg
# /kaggle/input/py-crack/Segmentation/Original image/60.jpg
# /kaggle/input/py-crack/Segmentation/Original image/221.jpg
# /kaggle/input/py-crack/Segmentation/Original image/167.jpg
# /kaggle/input/py-crack/Segmentation/Original image/57.jpg
# /kaggle/input/py-crack/Segmentation/Original image/227.jpg
# /kaggle/input/py-crack/Segmentation/Original image/112.jpg
# /kaggle/input/py-crack/Segmentation/Original image/193.jpg
# /kaggle/input/py-crack/Segmentation/Original image/152.jpg
# /kaggle/input/py-crack/Segmentation/Original image/368.jpg
# /kaggle/input/py-crack/Segmentation/Original image/192.jpg
# /kaggle/input/py-crack/Segmentation/Original image/91.jpg
# /kaggle/input/py-crack/Segmentation/Original image/9.jpg
# /kaggle/input/py-crack/Segmentation/Original image/101.jpg
# /kaggle/input/py-crack/Segmentation/Original image/99.jpg
# /kaggle/input/py-crack/Segmentation/Original image/311.jpg
# /kaggle/input/py-crack/Segmentation/Original image/241.jpg
# /kaggle/input/py-crack/Segmentation/Original image/37.jpg
# /kaggle/input/py-crack/Segmentation/Original image/340.jpg
# /kaggle/input/py-crack/Segmentation/Original image/1.jpg
# /kaggle/input/py-crack/Segmentation/Original image/177.jpg
# /kaggle/input/py-crack/Segmentation/Original image/186.jpg
# /kaggle/input/py-crack/Segmentation/Original image/358.jpg
# /kaggle/input/py-crack/Segmentation/Original image/69.jpg
# /kaggle/input/py-crack/Segmentation/Original image/75.jpg
# /kaggle/input/py-crack/Segmentation/Original image/117.jpg
# /kaggle/input/py-crack/Segmentation/Original image/81.jpg
# /kaggle/input/py-crack/Segmentation/Original image/299.jpg
# /kaggle/input/py-crack/Segmentation/Original image/254.jpg
# /kaggle/input/py-crack/Segmentation/Original image/276.jpg
# /kaggle/input/py-crack/Segmentation/Original image/46.jpg
# /kaggle/input/py-crack/Segmentation/Original image/319.jpg
# /kaggle/input/py-crack/Segmentation/Original image/137.jpg
# /kaggle/input/py-crack/Segmentation/Original image/267.jpg
# /kaggle/input/py-crack/Segmentation/Original image/44.jpg
# /kaggle/input/py-crack/Segmentation/Original image/65.jpg
# /kaggle/input/py-crack/Segmentation/Original image/50.jpg
# /kaggle/input/py-crack/Segmentation/Original image/314.jpg
# /kaggle/input/py-crack/Segmentation/Original image/127.jpg
# /kaggle/input/py-crack/Segmentation/Original image/196.jpg
# /kaggle/input/py-crack/Segmentation/Original image/29.jpg
# /kaggle/input/py-crack/Segmentation/Original image/140.jpg
# /kaggle/input/py-crack/Segmentation/Original image/235.jpg
# /kaggle/input/py-crack/Segmentation/Original image/322.jpg
# /kaggle/input/py-crack/Segmentation/Original image/79.jpg
# /kaggle/input/py-crack/Segmentation/Original image/302.jpg
# /kaggle/input/py-crack/Segmentation/Original image/179.jpg
# /kaggle/input/py-crack/Segmentation/Original image/284.jpg
# /kaggle/input/py-crack/Segmentation/Original image/285.jpg
# /kaggle/input/py-crack/Segmentation/Original image/105.jpg
# /kaggle/input/py-crack/Segmentation/Original image/16.jpg
# /kaggle/input/py-crack/Segmentation/Original image/111.jpg
# /kaggle/input/py-crack/Segmentation/Original image/55.jpg
# /kaggle/input/py-crack/Segmentation/Original image/317.jpg
# /kaggle/input/py-crack/Segmentation/Original image/356.jpg
# /kaggle/input/py-crack/Segmentation/Original image/145.jpg
# /kaggle/input/py-crack/Segmentation/Original image/135.jpg
# /kaggle/input/py-crack/Segmentation/Original image/23.jpg
# /kaggle/input/py-crack/Segmentation/Original image/246.jpg
# /kaggle/input/py-crack/Segmentation/Original image/7.jpg
# /kaggle/input/py-crack/Segmentation/Original image/214.jpg
# /kaggle/input/py-crack/Segmentation/Original image/225.jpg
# /kaggle/input/py-crack/Segmentation/Original image/252.jpg
# /kaggle/input/py-crack/Segmentation/Original image/77.jpg
# /kaggle/input/py-crack/Segmentation/Original image/166.jpg
# /kaggle/input/py-crack/Segmentation/Original image/292.jpg
# /kaggle/input/py-crack/Segmentation/Original image/80.jpg
# /kaggle/input/py-crack/Segmentation/Original image/159.jpg
# /kaggle/input/py-crack/Segmentation/Original image/121.jpg
# /kaggle/input/py-crack/Segmentation/Original image/28.jpg
# /kaggle/input/py-crack/Segmentation/Original image/22.jpg
# /kaggle/input/py-crack/Segmentation/Original image/173.jpg
# /kaggle/input/py-crack/Segmentation/Original image/171.jpg
# /kaggle/input/py-crack/Segmentation/Original image/329.jpg
# /kaggle/input/py-crack/Segmentation/Original image/258.jpg
# /kaggle/input/py-crack/Segmentation/Original image/103.jpg
# /kaggle/input/py-crack/Segmentation/Original image/174.jpg
# /kaggle/input/py-crack/Segmentation/Original image/40.jpg
# /kaggle/input/py-crack/Segmentation/Original image/261.jpg
# /kaggle/input/py-crack/Segmentation/Original image/357.jpg
# /kaggle/input/py-crack/Segmentation/Original image/332.jpg
# /kaggle/input/py-crack/Segmentation/Original image/296.jpg
# /kaggle/input/py-crack/Segmentation/Original image/346.jpg
# /kaggle/input/py-crack/Segmentation/Original image/308.jpg
# /kaggle/input/py-crack/Segmentation/Original image/264.jpg
# /kaggle/input/py-crack/Segmentation/Original image/199.jpg
# /kaggle/input/py-crack/Segmentation/Original image/310.jpg
# /kaggle/input/py-crack/Segmentation/Original image/126.jpg
# /kaggle/input/py-crack/Segmentation/Original image/142.jpg
# /kaggle/input/py-crack/Segmentation/Original image/48.jpg
# /kaggle/input/py-crack/Segmentation/Original image/339.jpg
# /kaggle/input/py-crack/Segmentation/Original image/280.jpg
# /kaggle/input/py-crack/Segmentation/Original image/169.jpg
# /kaggle/input/py-crack/Segmentation/Original image/194.jpg
# /kaggle/input/py-crack/Segmentation/Original image/180.jpg
# /kaggle/input/py-crack/Segmentation/Original image/104.jpg
# /kaggle/input/py-crack/Segmentation/Original image/24.jpg
# /kaggle/input/py-crack/Segmentation/Original image/155.jpg
# /kaggle/input/py-crack/Segmentation/Original image/88.jpg
# /kaggle/input/py-crack/Segmentation/Original image/344.jpg
# /kaggle/input/py-crack/Segmentation/Original image/64.jpg
# /kaggle/input/py-crack/Segmentation/Original image/352.jpg
# /kaggle/input/py-crack/Segmentation/Original image/287.jpg
# /kaggle/input/py-crack/Segmentation/Original image/269.jpg
# /kaggle/input/py-crack/Segmentation/Original image/326.jpg
# /kaggle/input/py-crack/Segmentation/Original image/216.jpg
# /kaggle/input/py-crack/Segmentation/Original image/158.jpg
# /kaggle/input/py-crack/Segmentation/Original image/148.jpg
# /kaggle/input/py-crack/Segmentation/Original image/168.jpg
# /kaggle/input/py-crack/Segmentation/Original image/31.jpg
# /kaggle/input/py-crack/Segmentation/Original image/263.jpg
# /kaggle/input/py-crack/Segmentation/Original image/195.jpg
# /kaggle/input/py-crack/Segmentation/Original image/255.jpg
# /kaggle/input/py-crack/Segmentation/Original image/114.jpg
# /kaggle/input/py-crack/Segmentation/Original image/281.jpg
# /kaggle/input/py-crack/Segmentation/Original image/43.jpg
# /kaggle/input/py-crack/Segmentation/Original image/138.jpg
# /kaggle/input/py-crack/Segmentation/Original image/207.jpg
# /kaggle/input/py-crack/Segmentation/Original image/209.jpg
# /kaggle/input/py-crack/Segmentation/Original image/100.jpg
# /kaggle/input/py-crack/Segmentation/Original image/13.jpg
# /kaggle/input/py-crack/Segmentation/Original image/228.jpg
# /kaggle/input/py-crack/Segmentation/Original image/74.jpg
# /kaggle/input/py-crack/Segmentation/Original image/323.jpg
# /kaggle/input/py-crack/Segmentation/Original image/337.jpg
# /kaggle/input/py-crack/Segmentation/Original image/223.jpg
# /kaggle/input/py-crack/Segmentation/Original image/350.jpg
# /kaggle/input/py-crack/Segmentation/Original image/236.jpg
# /kaggle/input/py-crack/Segmentation/Original image/363.jpg
# /kaggle/input/py-crack/Segmentation/Original image/68.jpg
# /kaggle/input/py-crack/Segmentation/Original image/53.jpg
# /kaggle/input/py-crack/Segmentation/Original image/83.jpg
# /kaggle/input/py-crack/Segmentation/Original image/336.jpg
# /kaggle/input/py-crack/Segmentation/Original image/107.jpg
# /kaggle/input/py-crack/Segmentation/Original image/347.jpg
# /kaggle/input/py-crack/Segmentation/Original image/354.jpg
# /kaggle/input/py-crack/Segmentation/Original image/154.jpg
# /kaggle/input/py-crack/Segmentation/Original image/206.jpg
# /kaggle/input/py-crack/Segmentation/Original image/164.jpg
# /kaggle/input/py-crack/Segmentation/Original image/338.jpg
# /kaggle/input/py-crack/Segmentation/Original image/301.jpg
# /kaggle/input/py-crack/Segmentation/Original image/146.jpg
# /kaggle/input/py-crack/Segmentation/Original image/161.jpg
# /kaggle/input/py-crack/Segmentation/Original image/198.jpg
# /kaggle/input/py-crack/Segmentation/Original image/277.jpg
# /kaggle/input/py-crack/Segmentation/Original image/331.jpg
# /kaggle/input/py-crack/Segmentation/Original image/72.jpg
# /kaggle/input/py-crack/Segmentation/Original image/257.jpg
# /kaggle/input/py-crack/Segmentation/Original image/233.jpg
# /kaggle/input/py-crack/Segmentation/Original image/139.jpg
# /kaggle/input/py-crack/Segmentation/Original image/318.jpg
# /kaggle/input/py-crack/Segmentation/Original image/200.jpg
# /kaggle/input/py-crack/Segmentation/Original image/321.jpg
# /kaggle/input/py-crack/Segmentation/Original image/32.jpg
# /kaggle/input/py-crack/Segmentation/Original image/102.jpg
# /kaggle/input/py-crack/Segmentation/Original image/244.jpg
# /kaggle/input/py-crack/Segmentation/Original image/220.jpg
# /kaggle/input/py-crack/Segmentation/Original image/17.jpg
# /kaggle/input/py-crack/Segmentation/Original image/157.jpg
# /kaggle/input/py-crack/Segmentation/Original image/26.jpg
# /kaggle/input/py-crack/Segmentation/Original image/351.jpg
# /kaggle/input/py-crack/Segmentation/Original image/183.jpg
# /kaggle/input/py-crack/Segmentation/Original image/39.jpg
# /kaggle/input/py-crack/Segmentation/Original image/219.jpg
# /kaggle/input/py-crack/Segmentation/Original image/240.jpg
# /kaggle/input/py-crack/Segmentation/Original image/288.jpg
# /kaggle/input/py-crack/Segmentation/Original image/360.jpg
# /kaggle/input/py-crack/Segmentation/Original image/242.jpg
# /kaggle/input/py-crack/Segmentation/Original image/86.jpg
# /kaggle/input/py-crack/Segmentation/Original image/229.jpg
# /kaggle/input/py-crack/Segmentation/Original image/222.jpg
# /kaggle/input/py-crack/Segmentation/Original image/330.jpg
# /kaggle/input/py-crack/Segmentation/Original image/15.jpg
# /kaggle/input/py-crack/Segmentation/Original image/238.jpg
# /kaggle/input/py-crack/Segmentation/Original image/119.jpg
# /kaggle/input/py-crack/Segmentation/Original image/165.jpg
# /kaggle/input/py-crack/Segmentation/Original image/204.jpg
# /kaggle/input/py-crack/Segmentation/Original image/12.jpg
# /kaggle/input/py-crack/Segmentation/Original image/224.jpg
# /kaggle/input/py-crack/Segmentation/Original image/141.jpg
# /kaggle/input/py-crack/Segmentation/Original image/92.jpg
# /kaggle/input/py-crack/Segmentation/Original image/122.jpg
# /kaggle/input/py-crack/Segmentation/Original image/293.jpg
# /kaggle/input/py-crack/Segmentation/Original image/305.jpg
# /kaggle/input/py-crack/Segmentation/Original image/11.jpg
# /kaggle/input/py-crack/Segmentation/Original image/70.jpg
# /kaggle/input/py-crack/Segmentation/Original image/210.jpg
# /kaggle/input/py-crack/Segmentation/Original image/181.jpg
# /kaggle/input/py-crack/Segmentation/Original image/259.jpg
# /kaggle/input/py-crack/Segmentation/Original image/34.jpg
# /kaggle/input/py-crack/Segmentation/Original image/27.jpg
# /kaggle/input/py-crack/Segmentation/Original image/294.jpg
# /kaggle/input/py-crack/Segmentation/Original image/51.jpg
# /kaggle/input/py-crack/Segmentation/Original image/262.jpg
# /kaggle/input/py-crack/Segmentation/Original image/132.jpg
# /kaggle/input/py-crack/Segmentation/Original image/52.jpg
# /kaggle/input/py-crack/Segmentation/Original image/341.jpg
# /kaggle/input/py-crack/Segmentation/Original image/21.jpg
# /kaggle/input/py-crack/Segmentation/Original image/4.jpg
# /kaggle/input/py-crack/Segmentation/Original image/309.jpg
# /kaggle/input/py-crack/Segmentation/Original image/365.jpg
# /kaggle/input/py-crack/Segmentation/Original image/312.jpg
# /kaggle/input/py-crack/Segmentation/Original image/184.jpg
# /kaggle/input/py-crack/Segmentation/Original image/300.jpg
# /kaggle/input/py-crack/Segmentation/Original image/250.jpg
# /kaggle/input/py-crack/Segmentation/Original image/297.jpg
# /kaggle/input/py-crack/Segmentation/Original image/125.jpg
# /kaggle/input/py-crack/Segmentation/Original image/128.jpg
# /kaggle/input/py-crack/Segmentation/Original image/172.jpg
# /kaggle/input/py-crack/Segmentation/Original image/95.jpg
# /kaggle/input/py-crack/Segmentation/Original image/3.jpg
# /kaggle/input/py-crack/Segmentation/Original image/36.jpg
# /kaggle/input/py-crack/Segmentation/Original image/217.jpg
# /kaggle/input/py-crack/Segmentation/Original image/96.jpg
# /kaggle/input/py-crack/Segmentation/Original image/348.jpg
# /kaggle/input/py-crack/Segmentation/Original image/144.jpg
# /kaggle/input/py-crack/Segmentation/Original image/110.jpg
# /kaggle/input/py-crack/Segmentation/Original image/325.jpg
# /kaggle/input/py-crack/Segmentation/Original image/63.jpg
# /kaggle/input/py-crack/Segmentation/Original image/162.jpg
# /kaggle/input/py-crack/Segmentation/Original image/231.jpg
# /kaggle/input/py-crack/Segmentation/Original image/19.jpg
# /kaggle/input/py-crack/Segmentation/Original image/201.jpg
# /kaggle/input/py-crack/Segmentation/Original image/303.jpg
# /kaggle/input/py-crack/Segmentation/Original image/87.jpg
# /kaggle/input/py-crack/Segmentation/Original image/47.jpg
# /kaggle/input/py-crack/Segmentation/Original image/282.jpg
# /kaggle/input/py-crack/Segmentation/Original image/93.jpg
# /kaggle/input/py-crack/Segmentation/Original image/170.jpg
# /kaggle/input/py-crack/Segmentation/Original image/324.jpg
# /kaggle/input/py-crack/Segmentation/Original image/14.jpg
# /kaggle/input/py-crack/Segmentation/Original image/18.jpg
# /kaggle/input/py-crack/Segmentation/Original image/175.jpg
# /kaggle/input/py-crack/Segmentation/Original image/268.jpg
# /kaggle/input/py-crack/Segmentation/Original image/345.jpg
# /kaggle/input/py-crack/Segmentation/Original image/316.jpg
# /kaggle/input/py-crack/Segmentation/Original image/226.jpg
# /kaggle/input/py-crack/Segmentation/Original image/116.jpg
# /kaggle/input/py-crack/Segmentation/Original image/78.jpg
# /kaggle/input/py-crack/Segmentation/Original image/320.jpg
# /kaggle/input/py-crack/Segmentation/Original image/367.jpg
# /kaggle/input/py-crack/Segmentation/Original image/266.jpg
# /kaggle/input/py-crack/Segmentation/Original image/245.jpg
# /kaggle/input/py-crack/Segmentation/Original image/335.jpg
# /kaggle/input/py-crack/Segmentation/Original image/232.jpg
# /kaggle/input/py-crack/Segmentation/Original image/108.jpg
# /kaggle/input/py-crack/Segmentation/Original image/49.jpg
# /kaggle/input/py-crack/Segmentation/Original image/203.jpg
# /kaggle/input/py-crack/Segmentation/Original image/66.jpg
# /kaggle/input/py-crack/Segmentation/Original image/298.jpg
# /kaggle/input/py-crack/Segmentation/Original image/306.jpg
# /kaggle/input/py-crack/Segmentation/Original image/307.jpg
# /kaggle/input/py-crack/Segmentation/Original image/129.jpg
# /kaggle/input/py-crack/Segmentation/Original image/2.jpg
# /kaggle/input/py-crack/Segmentation/Original image/205.jpg
# /kaggle/input/py-crack/Segmentation/Original image/133.jpg
# /kaggle/input/py-crack/Segmentation/Original image/304.jpg
# /kaggle/input/py-crack/Segmentation/Original image/315.jpg
# /kaggle/input/py-crack/Segmentation/Original image/134.jpg
# /kaggle/input/py-crack/Segmentation/Original image/218.jpg
# /kaggle/input/py-crack/Segmentation/Original image/249.jpg
# /kaggle/input/py-crack/Segmentation/Original image/213.jpg
# /kaggle/input/py-crack/Segmentation/Original image/136.jpg
# /kaggle/input/py-crack/Segmentation/Original image/364.jpg
# /kaggle/input/py-crack/Segmentation/Original image/90.jpg
# /kaggle/input/py-crack/Segmentation/Original image/25.jpg
# /kaggle/input/py-crack/Segmentation/Original image/147.jpg
# /kaggle/input/py-crack/Classification/With crack/208.jpg
# /kaggle/input/py-crack/Classification/With crack/333.jpg
# /kaggle/input/py-crack/Classification/With crack/45.jpg
# /kaggle/input/py-crack/Classification/With crack/369.jpg
# /kaggle/input/py-crack/Classification/With crack/56.jpg
# /kaggle/input/py-crack/Classification/With crack/89.jpg
# /kaggle/input/py-crack/Classification/With crack/20.jpg
# /kaggle/input/py-crack/Classification/With crack/275.jpg
# /kaggle/input/py-crack/Classification/With crack/212.jpg
# /kaggle/input/py-crack/Classification/With crack/239.jpg
# /kaggle/input/py-crack/Classification/With crack/58.jpg
# /kaggle/input/py-crack/Classification/With crack/150.jpg
# /kaggle/input/py-crack/Classification/With crack/6.jpg
# /kaggle/input/py-crack/Classification/With crack/109.jpg
# /kaggle/input/py-crack/Classification/With crack/149.jpg
# /kaggle/input/py-crack/Classification/With crack/187.jpg
# /kaggle/input/py-crack/Classification/With crack/76.jpg
# /kaggle/input/py-crack/Classification/With crack/355.jpg
# /kaggle/input/py-crack/Classification/With crack/71.jpg
# /kaggle/input/py-crack/Classification/With crack/342.jpg
# /kaggle/input/py-crack/Classification/With crack/272.jpg
# /kaggle/input/py-crack/Classification/With crack/270.jpg
# /kaggle/input/py-crack/Classification/With crack/182.jpg
# /kaggle/input/py-crack/Classification/With crack/215.jpg
# /kaggle/input/py-crack/Classification/With crack/185.jpg
# /kaggle/input/py-crack/Classification/With crack/243.jpg
# /kaggle/input/py-crack/Classification/With crack/153.jpg
# /kaggle/input/py-crack/Classification/With crack/189.jpg
# /kaggle/input/py-crack/Classification/With crack/143.jpg
# /kaggle/input/py-crack/Classification/With crack/327.jpg
# /kaggle/input/py-crack/Classification/With crack/253.jpg
# /kaggle/input/py-crack/Classification/With crack/343.jpg
# /kaggle/input/py-crack/Classification/With crack/115.jpg
# /kaggle/input/py-crack/Classification/With crack/131.jpg
# /kaggle/input/py-crack/Classification/With crack/5.jpg
# /kaggle/input/py-crack/Classification/With crack/366.jpg
# /kaggle/input/py-crack/Classification/With crack/151.jpg
# /kaggle/input/py-crack/Classification/With crack/8.jpg
# /kaggle/input/py-crack/Classification/With crack/260.jpg
# /kaggle/input/py-crack/Classification/With crack/202.jpg
# /kaggle/input/py-crack/Classification/With crack/84.jpg
# /kaggle/input/py-crack/Classification/With crack/237.jpg
# /kaggle/input/py-crack/Classification/With crack/273.jpg
# /kaggle/input/py-crack/Classification/With crack/286.jpg
# /kaggle/input/py-crack/Classification/With crack/283.jpg
# /kaggle/input/py-crack/Classification/With crack/85.jpg
# /kaggle/input/py-crack/Classification/With crack/359.jpg
# /kaggle/input/py-crack/Classification/With crack/67.jpg
# /kaggle/input/py-crack/Classification/With crack/265.jpg
# /kaggle/input/py-crack/Classification/With crack/289.jpg
# /kaggle/input/py-crack/Classification/With crack/118.jpg
# /kaggle/input/py-crack/Classification/With crack/361.jpg
# /kaggle/input/py-crack/Classification/With crack/82.jpg
# /kaggle/input/py-crack/Classification/With crack/295.jpg
# /kaggle/input/py-crack/Classification/With crack/176.jpg
# /kaggle/input/py-crack/Classification/With crack/279.jpg
# /kaggle/input/py-crack/Classification/With crack/30.jpg
# /kaggle/input/py-crack/Classification/With crack/97.jpg
# /kaggle/input/py-crack/Classification/With crack/334.jpg
# /kaggle/input/py-crack/Classification/With crack/106.jpg
# /kaggle/input/py-crack/Classification/With crack/163.jpg
# /kaggle/input/py-crack/Classification/With crack/113.jpg
# /kaggle/input/py-crack/Classification/With crack/160.jpg
# /kaggle/input/py-crack/Classification/With crack/38.jpg
# /kaggle/input/py-crack/Classification/With crack/349.jpg
# /kaggle/input/py-crack/Classification/With crack/328.jpg
# /kaggle/input/py-crack/Classification/With crack/211.jpg
# /kaggle/input/py-crack/Classification/With crack/42.jpg
# /kaggle/input/py-crack/Classification/With crack/291.jpg
# /kaggle/input/py-crack/Classification/With crack/197.jpg
# /kaggle/input/py-crack/Classification/With crack/33.jpg
# /kaggle/input/py-crack/Classification/With crack/10.jpg
# /kaggle/input/py-crack/Classification/With crack/234.jpg
# /kaggle/input/py-crack/Classification/With crack/178.jpg
# /kaggle/input/py-crack/Classification/With crack/54.jpg
# /kaggle/input/py-crack/Classification/With crack/271.jpg
# /kaggle/input/py-crack/Classification/With crack/251.jpg
# /kaggle/input/py-crack/Classification/With crack/130.jpg
# /kaggle/input/py-crack/Classification/With crack/62.jpg
# /kaggle/input/py-crack/Classification/With crack/278.jpg
# /kaggle/input/py-crack/Classification/With crack/156.jpg
# /kaggle/input/py-crack/Classification/With crack/120.jpg
# /kaggle/input/py-crack/Classification/With crack/35.jpg
# /kaggle/input/py-crack/Classification/With crack/290.jpg
# /kaggle/input/py-crack/Classification/With crack/61.jpg
# /kaggle/input/py-crack/Classification/With crack/190.jpg
# /kaggle/input/py-crack/Classification/With crack/124.jpg
# /kaggle/input/py-crack/Classification/With crack/353.jpg
# /kaggle/input/py-crack/Classification/With crack/191.jpg
# /kaggle/input/py-crack/Classification/With crack/59.jpg
# /kaggle/input/py-crack/Classification/With crack/73.jpg
# /kaggle/input/py-crack/Classification/With crack/313.jpg
# /kaggle/input/py-crack/Classification/With crack/188.jpg
# /kaggle/input/py-crack/Classification/With crack/274.jpg
# /kaggle/input/py-crack/Classification/With crack/98.jpg
# ...
# /kaggle/input/py-crack/Classification/With crack/21.jpg
# /kaggle/input/py-crack/Classification/With crack/4.jpg
# /kaggle/input/py-crack/Classification/With crack/309.jpg
# /kaggle/input/py-crack/Classification/With crack/365.jpg
# /kaggle/input/py-crack/Classification/With crack/312.jpg
# /kaggle/input/py-crack/Classification/With crack/184.jpg
# /kaggle/input/py-crack/Classification/With crack/300.jpg
# /kaggle/input/py-crack/Classification/With crack/250.jpg
# /kaggle/input/py-crack/Classification/With crack/297.jpg
# /kaggle/input/py-crack/Classification/With crack/125.jpg
# /kaggle/input/py-crack/Classification/With crack/128.jpg
# /kaggle/input/py-crack/Classification/With crack/172.jpg
# /kaggle/input/py-crack/Classification/With crack/95.jpg
# /kaggle/input/py-crack/Classification/With crack/3.jpg
# /kaggle/input/py-crack/Classification/With crack/36.jpg
# /kaggle/input/py-crack/Classification/With crack/217.jpg
# /kaggle/input/py-crack/Classification/With crack/96.jpg
# /kaggle/input/py-crack/Classification/With crack/348.jpg
# /kaggle/input/py-crack/Classification/With crack/144.jpg
# /kaggle/input/py-crack/Classification/With crack/110.jpg
# /kaggle/input/py-crack/Classification/With crack/325.jpg
# /kaggle/input/py-crack/Classification/With crack/63.jpg
# /kaggle/input/py-crack/Classification/With crack/162.jpg
# /kaggle/input/py-crack/Classification/With crack/231.jpg
# /kaggle/input/py-crack/Classification/With crack/19.jpg
# /kaggle/input/py-crack/Classification/With crack/201.jpg
# /kaggle/input/py-crack/Classification/With crack/303.jpg
# /kaggle/input/py-crack/Classification/With crack/87.jpg
# /kaggle/input/py-crack/Classification/With crack/47.jpg
# /kaggle/input/py-crack/Classification/With crack/282.jpg
# /kaggle/input/py-crack/Classification/With crack/93.jpg
# /kaggle/input/py-crack/Classification/With crack/170.jpg
# /kaggle/input/py-crack/Classification/With crack/324.jpg
# /kaggle/input/py-crack/Classification/With crack/14.jpg
# /kaggle/input/py-crack/Classification/With crack/18.jpg
# /kaggle/input/py-crack/Classification/With crack/175.jpg
# /kaggle/input/py-crack/Classification/With crack/268.jpg
# /kaggle/input/py-crack/Classification/With crack/345.jpg
# /kaggle/input/py-crack/Classification/With crack/316.jpg
# /kaggle/input/py-crack/Classification/With crack/226.jpg
# /kaggle/input/py-crack/Classification/With crack/116.jpg
# /kaggle/input/py-crack/Classification/With crack/78.jpg
# /kaggle/input/py-crack/Classification/With crack/320.jpg
# /kaggle/input/py-crack/Classification/With crack/367.jpg
# /kaggle/input/py-crack/Classification/With crack/266.jpg
# /kaggle/input/py-crack/Classification/With crack/245.jpg
# /kaggle/input/py-crack/Classification/With crack/335.jpg
# /kaggle/input/py-crack/Classification/With crack/232.jpg
# /kaggle/input/py-crack/Classification/With crack/108.jpg
# /kaggle/input/py-crack/Classification/With crack/49.jpg
# /kaggle/input/py-crack/Classification/With crack/203.jpg
# /kaggle/input/py-crack/Classification/With crack/66.jpg
# /kaggle/input/py-crack/Classification/With crack/298.jpg
# /kaggle/input/py-crack/Classification/With crack/306.jpg
# /kaggle/input/py-crack/Classification/With crack/307.jpg
# /kaggle/input/py-crack/Classification/With crack/129.jpg
# /kaggle/input/py-crack/Classification/With crack/2.jpg
# /kaggle/input/py-crack/Classification/With crack/205.jpg
# /kaggle/input/py-crack/Classification/With crack/133.jpg
# /kaggle/input/py-crack/Classification/With crack/304.jpg
# /kaggle/input/py-crack/Classification/With crack/315.jpg
# /kaggle/input/py-crack/Classification/With crack/134.jpg
# /kaggle/input/py-crack/Classification/With crack/218.jpg
# /kaggle/input/py-crack/Classification/With crack/249.jpg
# /kaggle/input/py-crack/Classification/With crack/213.jpg
# /kaggle/input/py-crack/Classification/With crack/136.jpg
# /kaggle/input/py-crack/Classification/With crack/364.jpg
# /kaggle/input/py-crack/Classification/With crack/90.jpg
# /kaggle/input/py-crack/Classification/With crack/25.jpg
# /kaggle/input/py-crack/Classification/With crack/147.jpg
# /kaggle/input/py-crack/Classification/Without crack/473.jpg
# /kaggle/input/py-crack/Classification/Without crack/537.jpg
# /kaggle/input/py-crack/Classification/Without crack/521.jpg
# /kaggle/input/py-crack/Classification/Without crack/436.jpg
# /kaggle/input/py-crack/Classification/Without crack/539.jpg
# /kaggle/input/py-crack/Classification/Without crack/516.jpg
# /kaggle/input/py-crack/Classification/Without crack/474.jpg
# /kaggle/input/py-crack/Classification/Without crack/501.jpg
# /kaggle/input/py-crack/Classification/Without crack/429.jpg
# /kaggle/input/py-crack/Classification/Without crack/544.jpg
# /kaggle/input/py-crack/Classification/Without crack/377.jpg
# /kaggle/input/py-crack/Classification/Without crack/489.jpg
# /kaggle/input/py-crack/Classification/Without crack/476.jpg
# /kaggle/input/py-crack/Classification/Without crack/446.jpg
# /kaggle/input/py-crack/Classification/Without crack/425.jpg
# /kaggle/input/py-crack/Classification/Without crack/426.jpg
# /kaggle/input/py-crack/Classification/Without crack/503.jpg
# /kaggle/input/py-crack/Classification/Without crack/440.jpg
# /kaggle/input/py-crack/Classification/Without crack/534.jpg
# /kaggle/input/py-crack/Classification/Without crack/486.jpg
# /kaggle/input/py-crack/Classification/Without crack/513.jpg
# /kaggle/input/py-crack/Classification/Without crack/564.jpg
# /kaggle/input/py-crack/Classification/Without crack/443.jpg
# /kaggle/input/py-crack/Classification/Without crack/518.jpg
# /kaggle/input/py-crack/Classification/Without crack/463.jpg
# /kaggle/input/py-crack/Classification/Without crack/490.jpg
# /kaggle/input/py-crack/Classification/Without crack/500.jpg
# /kaggle/input/py-crack/Classification/Without crack/380.jpg
# /kaggle/input/py-crack/Classification/Without crack/558.jpg
# /kaggle/input/py-crack/Classification/Without crack/456.jpg
# /kaggle/input/py-crack/Classification/Without crack/441.jpg
# /kaggle/input/py-crack/Classification/Without crack/512.jpg
# /kaggle/input/py-crack/Classification/Without crack/427.jpg
# /kaggle/input/py-crack/Classification/Without crack/379.jpg
# /kaggle/input/py-crack/Classification/Without crack/375.jpg
# /kaggle/input/py-crack/Classification/Without crack/396.jpg
# /kaggle/input/py-crack/Classification/Without crack/480.jpg
# /kaggle/input/py-crack/Classification/Without crack/527.jpg
# /kaggle/input/py-crack/Classification/Without crack/408.jpg
# /kaggle/input/py-crack/Classification/Without crack/509.jpg
# /kaggle/input/py-crack/Classification/Without crack/559.jpg
# /kaggle/input/py-crack/Classification/Without crack/477.jpg
# /kaggle/input/py-crack/Classification/Without crack/538.jpg
# /kaggle/input/py-crack/Classification/Without crack/515.jpg
# /kaggle/input/py-crack/Classification/Without crack/372.jpg
# /kaggle/input/py-crack/Classification/Without crack/388.jpg
# /kaggle/input/py-crack/Classification/Without crack/478.jpg
# /kaggle/input/py-crack/Classification/Without crack/374.jpg
# /kaggle/input/py-crack/Classification/Without crack/452.jpg
# /kaggle/input/py-crack/Classification/Without crack/506.jpg
# /kaggle/input/py-crack/Classification/Without crack/412.jpg
# /kaggle/input/py-crack/Classification/Without crack/382.jpg
# /kaggle/input/py-crack/Classification/Without crack/397.jpg
# /kaggle/input/py-crack/Classification/Without crack/435.jpg
# /kaggle/input/py-crack/Classification/Without crack/524.jpg
# /kaggle/input/py-crack/Classification/Without crack/529.jpg
# /kaggle/input/py-crack/Classification/Without crack/468.jpg
# /kaggle/input/py-crack/Classification/Without crack/414.jpg
# /kaggle/input/py-crack/Classification/Without crack/403.jpg
# /kaggle/input/py-crack/Classification/Without crack/390.jpg
# /kaggle/input/py-crack/Classification/Without crack/410.jpg
# /kaggle/input/py-crack/Classification/Without crack/381.jpg
# /kaggle/input/py-crack/Classification/Without crack/535.jpg
# /kaggle/input/py-crack/Classification/Without crack/393.jpg
# /kaggle/input/py-crack/Classification/Without crack/424.jpg
# /kaggle/input/py-crack/Classification/Without crack/494.jpg
# /kaggle/input/py-crack/Classification/Without crack/481.jpg
# /kaggle/input/py-crack/Classification/Without crack/401.jpg
# /kaggle/input/py-crack/Classification/Without crack/444.jpg
# /kaggle/input/py-crack/Classification/Without crack/560.jpg
# /kaggle/input/py-crack/Classification/Without crack/525.jpg
# /kaggle/input/py-crack/Classification/Without crack/455.jpg
# /kaggle/input/py-crack/Classification/Without crack/561.jpg
# /kaggle/input/py-crack/Classification/Without crack/563.jpg
# /kaggle/input/py-crack/Classification/Without crack/467.jpg
# /kaggle/input/py-crack/Classification/Without crack/530.jpg
# /kaggle/input/py-crack/Classification/Without crack/569.jpg
# /kaggle/input/py-crack/Classification/Without crack/531.jpg
# /kaggle/input/py-crack/Classification/Without crack/415.jpg
# /kaggle/input/py-crack/Classification/Without crack/482.jpg
# /kaggle/input/py-crack/Classification/Without crack/419.jpg
# /kaggle/input/py-crack/Classification/Without crack/387.jpg
# /kaggle/input/py-crack/Classification/Without crack/371.jpg
# /kaggle/input/py-crack/Classification/Without crack/541.jpg
# /kaggle/input/py-crack/Classification/Without crack/548.jpg
# /kaggle/input/py-crack/Classification/Without crack/434.jpg
# /kaggle/input/py-crack/Classification/Without crack/466.jpg
# /kaggle/input/py-crack/Classification/Without crack/430.jpg
# /kaggle/input/py-crack/Classification/Without crack/464.jpg
# /kaggle/input/py-crack/Classification/Without crack/458.jpg
# /kaggle/input/py-crack/Classification/Without crack/378.jpg
# /kaggle/input/py-crack/Classification/Without crack/400.jpg
# /kaggle/input/py-crack/Classification/Without crack/498.jpg
# /kaggle/input/py-crack/Classification/Without crack/565.jpg
# /kaggle/input/py-crack/Classification/Without crack/392.jpg
# /kaggle/input/py-crack/Classification/Without crack/391.jpg
# /kaggle/input/py-crack/Classification/Without crack/451.jpg
# /kaggle/input/py-crack/Classification/Without crack/543.jpg
# /kaggle/input/py-crack/Classification/Without crack/554.jpg
# /kaggle/input/py-crack/Classification/Without crack/532.jpg
# /kaggle/input/py-crack/Classification/Without crack/555.jpg
# /kaggle/input/py-crack/Classification/Without crack/421.jpg
# /kaggle/input/py-crack/Classification/Without crack/545.jpg
# /kaggle/input/py-crack/Classification/Without crack/449.jpg
# /kaggle/input/py-crack/Classification/Without crack/567.jpg
# /kaggle/input/py-crack/Classification/Without crack/465.jpg
# /kaggle/input/py-crack/Classification/Without crack/420.jpg
# /kaggle/input/py-crack/Classification/Without crack/485.jpg
# /kaggle/input/py-crack/Classification/Without crack/450.jpg
# /kaggle/input/py-crack/Classification/Without crack/502.jpg
# /kaggle/input/py-crack/Classification/Without crack/552.jpg
# /kaggle/input/py-crack/Classification/Without crack/406.jpg
# /kaggle/input/py-crack/Classification/Without crack/496.jpg
# /kaggle/input/py-crack/Classification/Without crack/376.jpg
# /kaggle/input/py-crack/Classification/Without crack/507.jpg
# /kaggle/input/py-crack/Classification/Without crack/417.jpg
# /kaggle/input/py-crack/Classification/Without crack/447.jpg
# /kaggle/input/py-crack/Classification/Without crack/528.jpg
# /kaggle/input/py-crack/Classification/Without crack/445.jpg
# /kaggle/input/py-crack/Classification/Without crack/416.jpg
# /kaggle/input/py-crack/Classification/Without crack/488.jpg
# /kaggle/input/py-crack/Classification/Without crack/469.jpg
# /kaggle/input/py-crack/Classification/Without crack/394.jpg
# /kaggle/input/py-crack/Classification/Without crack/492.jpg
# /kaggle/input/py-crack/Classification/Without crack/438.jpg
# /kaggle/input/py-crack/Classification/Without crack/373.jpg
# /kaggle/input/py-crack/Classification/Without crack/459.jpg
# /kaggle/input/py-crack/Classification/Without crack/523.jpg
# /kaggle/input/py-crack/Classification/Without crack/383.jpg
# /kaggle/input/py-crack/Classification/Without crack/402.jpg
# /kaggle/input/py-crack/Classification/Without crack/557.jpg
# /kaggle/input/py-crack/Classification/Without crack/487.jpg
# /kaggle/input/py-crack/Classification/Without crack/566.jpg
# /kaggle/input/py-crack/Classification/Without crack/495.jpg
# /kaggle/input/py-crack/Classification/Without crack/497.jpg
# /kaggle/input/py-crack/Classification/Without crack/491.jpg
# /kaggle/input/py-crack/Classification/Without crack/439.jpg
# /kaggle/input/py-crack/Classification/Without crack/453.jpg
# /kaggle/input/py-crack/Classification/Without crack/484.jpg
# /kaggle/input/py-crack/Classification/Without crack/405.jpg
# /kaggle/input/py-crack/Classification/Without crack/533.jpg
# /kaggle/input/py-crack/Classification/Without crack/568.jpg
# /kaggle/input/py-crack/Classification/Without crack/550.jpg
# /kaggle/input/py-crack/Classification/Without crack/472.jpg
# /kaggle/input/py-crack/Classification/Without crack/389.jpg
# /kaggle/input/py-crack/Classification/Without crack/411.jpg
# /kaggle/input/py-crack/Classification/Without crack/520.jpg
# /kaggle/input/py-crack/Classification/Without crack/432.jpg
# /kaggle/input/py-crack/Classification/Without crack/370.jpg
# /kaggle/input/py-crack/Classification/Without crack/399.jpg
# /kaggle/input/py-crack/Classification/Without crack/479.jpg
# /kaggle/input/py-crack/Classification/Without crack/409.jpg
# /kaggle/input/py-crack/Classification/Without crack/448.jpg
# /kaggle/input/py-crack/Classification/Without crack/546.jpg
# /kaggle/input/py-crack/Classification/Without crack/418.jpg
# /kaggle/input/py-crack/Classification/Without crack/556.jpg
# /kaggle/input/py-crack/Classification/Without crack/540.jpg
# /kaggle/input/py-crack/Classification/Without crack/493.jpg
# /kaggle/input/py-crack/Classification/Without crack/553.jpg
# /kaggle/input/py-crack/Classification/Without crack/442.jpg
# /kaggle/input/py-crack/Classification/Without crack/384.jpg
# /kaggle/input/py-crack/Classification/Without crack/536.jpg
# /kaggle/input/py-crack/Classification/Without crack/386.jpg
# /kaggle/input/py-crack/Classification/Without crack/404.jpg
# /kaggle/input/py-crack/Classification/Without crack/413.jpg
# /kaggle/input/py-crack/Classification/Without crack/407.jpg
# /kaggle/input/py-crack/Classification/Without crack/522.jpg
# /kaggle/input/py-crack/Classification/Without crack/510.jpg
# /kaggle/input/py-crack/Classification/Without crack/437.jpg
# /kaggle/input/py-crack/Classification/Without crack/385.jpg
# /kaggle/input/py-crack/Classification/Without crack/475.jpg
# /kaggle/input/py-crack/Classification/Without crack/471.jpg
# /kaggle/input/py-crack/Classification/Without crack/398.jpg
# /kaggle/input/py-crack/Classification/Without crack/499.jpg
# /kaggle/input/py-crack/Classification/Without crack/508.jpg
# /kaggle/input/py-crack/Classification/Without crack/514.jpg
# /kaggle/input/py-crack/Classification/Without crack/562.jpg
# /kaggle/input/py-crack/Classification/Without crack/547.jpg
# /kaggle/input/py-crack/Classification/Without crack/470.jpg
# /kaggle/input/py-crack/Classification/Without crack/428.jpg
# /kaggle/input/py-crack/Classification/Without crack/457.jpg
# /kaggle/input/py-crack/Classification/Without crack/549.jpg
# /kaggle/input/py-crack/Classification/Without crack/519.jpg
# /kaggle/input/py-crack/Classification/Without crack/517.jpg
# /kaggle/input/py-crack/Classification/Without crack/526.jpg
# /kaggle/input/py-crack/Classification/Without crack/462.jpg
# /kaggle/input/py-crack/Classification/Without crack/433.jpg
# /kaggle/input/py-crack/Classification/Without crack/460.jpg
# /kaggle/input/py-crack/Classification/Without crack/542.jpg
# /kaggle/input/py-crack/Classification/Without crack/505.jpg
# /kaggle/input/py-crack/Classification/Without crack/511.jpg
# /kaggle/input/py-crack/Classification/Without crack/483.jpg
# /kaggle/input/py-crack/Classification/Without crack/395.jpg
# /kaggle/input/py-crack/Classification/Without crack/423.jpg
# /kaggle/input/py-crack/Classification/Without crack/504.jpg
# /kaggle/input/py-crack/Classification/Without crack/422.jpg
# /kaggle/input/py-crack/Classification/Without crack/551.jpg
# /kaggle/input/py-crack/Classification/Without crack/431.jpg
# /kaggle/input/py-crack/Classification/Without crack/461.jpg
# /kaggle/input/py-crack/Classification/Without crack/454.jpg

# %%
# IMPORTS & DEVICE


import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from collections import Counter
import numpy as np

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %%
# 2. DATA PATHS & TRANSFORMS 


data_root = "/kaggle/input/py-crack/Classification"

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5],
                         [0.5, 0.5, 0.5])
])

full_dataset = datasets.ImageFolder(data_root, transform=transform)
num_classes = len(full_dataset.classes)
print("Classes:", full_dataset.classes)

# Check overall class distribution
print("Full dataset distribution:", Counter(full_dataset.targets))
# Out:
# Classes: ['With crack', 'Without crack']
# Full dataset distribution: Counter({0: 369, 1: 200})

# %%
#  TRAIN & VALIDATION SPLIT


train_ratio = 0.8
train_size = int(train_ratio * len(full_dataset))
val_size   = len(full_dataset) - train_size

train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

print(f"Train size: {len(train_dataset)}, Val size: {len(val_dataset)}")

batch_size = 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset,   batch_size=batch_size, shuffle=False)
# Out:
# Train size: 455, Val size: 114

# %%
#  CUSTOM CNN MODEL 


class CrackCNN(nn.Module):
    def __init__(self, num_classes):
        super(CrackCNN, self).__init__()

        self.features = nn.Sequential(
            
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2),        

            
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),        

            
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),        

    
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),        
        )

        
        self.global_pool = nn.AdaptiveAvgPool2d((1, 1))  

        self.classifier = nn.Sequential(
            nn.Flatten(),             
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)   # final fully connected layer
        )

    def forward(self, x):
        x = self.features(x)
        x = self.global_pool(x)
        x = self.classifier(x)
        return x

model = CrackCNN(num_classes).to(device)
print(model)
# Out:
# CrackCNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (global_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=256, out_features=256, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=2, bias=True)
#   )
# )

# %%
#  LOSS, CLASS WEIGHTS, OPTIMIZER, HYPERPARAMETERS


labels_np = np.array(full_dataset.targets)
class_counts = Counter(full_dataset.targets)
print("Class counts:", class_counts)

class_weights_np = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(labels_np),
    y=labels_np
)
class_weights = torch.tensor(class_weights_np, dtype=torch.float).to(device)
print("Class weights:", class_weights)

criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=1e-4)  

num_epochs    = 20      
min_epochs    = 5       
patience      = 5       
best_val_loss = np.inf
patience_counter = 0

train_losses = []
val_losses   = []
# Out:
# Class counts: Counter({0: 369, 1: 200})
# Class weights: tensor([0.7710, 1.4225])

# %%
#  TRAINING LOOP + VALIDATION + EARLY STOPPING


for epoch in range(num_epochs):

    model.train()
    running_train_loss = 0.0

    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_train_loss += loss.item()

    epoch_train_loss = running_train_loss / len(train_loader)
    train_losses.append(epoch_train_loss)

    
    model.eval()
    running_val_loss = 0.0

    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()

    epoch_val_loss = running_val_loss / len(val_loader)
    val_losses.append(epoch_val_loss)

    print(f"Epoch [{epoch+1}/{num_epochs}] "
          f"- Train Loss: {epoch_train_loss:.4f} | Val Loss: {epoch_val_loss:.4f}")

    
    if epoch_val_loss < best_val_loss:
        best_val_loss = epoch_val_loss
        patience_counter = 0
        best_state_dict = model.state_dict()   # save best model
    else:
        patience_counter += 1

    if (epoch + 1) >= min_epochs and patience_counter >= patience:
        print("Early stopping triggered.")
        break


model.load_state_dict(best_state_dict)
# Out:
# Epoch [1/20] - Train Loss: 0.5650 | Val Loss: 0.7133
# Epoch [2/20] - Train Loss: 0.4329 | Val Loss: 0.6478
# Epoch [3/20] - Train Loss: 0.3584 | Val Loss: 0.4140
# Epoch [4/20] - Train Loss: 0.3523 | Val Loss: 0.3969
# Epoch [5/20] - Train Loss: 0.3539 | Val Loss: 0.2904
# Epoch [6/20] - Train Loss: 0.2877 | Val Loss: 0.2486
# Epoch [7/20] - Train Loss: 0.2420 | Val Loss: 0.2228
# Epoch [8/20] - Train Loss: 0.2390 | Val Loss: 0.2040
# Epoch [9/20] - Train Loss: 0.2120 | Val Loss: 0.2737
# Epoch [10/20] - Train Loss: 0.2364 | Val Loss: 0.2214
# Epoch [11/20] - Train Loss: 0.1712 | Val Loss: 0.1783
# Epoch [12/20] - Train Loss: 0.1835 | Val Loss: 0.2473
# Epoch [13/20] - Train Loss: 0.1827 | Val Loss: 0.1422
# Epoch [14/20] - Train Loss: 0.1447 | Val Loss: 0.2685
# Epoch [15/20] - Train Loss: 0.1916 | Val Loss: 0.1351
# Epoch [16/20] - Train Loss: 0.1528 | Val Loss: 0.1629
# Epoch [17/20] - Train Loss: 0.1592 | Val Loss: 0.2436
# Epoch [18/20] - Train Loss: 0.1477 | Val Loss: 0.1210
# Epoch [19/20] - Train Loss: 0.1814 | Val Loss: 0.2328
# Epoch [20/20] - Train Loss: 0.1515 | Val Loss: 0.1648
# <All keys matched successfully>

# %%
#  EVALUATION 


model.eval()
y_true = []
y_pred = []

with torch.no_grad():
    for images, labels in val_loader:
        images = images.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)

        y_true.extend(labels.numpy())
        y_pred.extend(preds.cpu().numpy())

y_true = np.array(y_true)
y_pred = np.array(y_pred)

accuracy = (y_true == y_pred).mean()
print(f"\nFinal Accuracy on Validation Set: {accuracy:.4f}")

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=full_dataset.classes))


print("\nConfusion Matrix:")
print(confusion_matrix(y_true, y_pred))
# Out:
# Final Accuracy on Validation Set: 0.9211
#
# Classification Report:
#                precision    recall  f1-score   support
#
#    With crack       0.96      0.92      0.94        74
# Without crack       0.86      0.93      0.89        40
#
#      accuracy                           0.92       114
#     macro avg       0.91      0.92      0.91       114
#  weighted avg       0.92      0.92      0.92       114
#
#
# Confusion Matrix:
# [[68  6]
#  [ 3 37]]
